# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading data

# %%
paris_ml = pd.read_csv(r'C:\Users\radek\Git-Hub\Final_Project_Ironhack\04 - Data Cleaning\Paris.csv')

# %%
paris_ml.head()
# Out:
#    latitude  longitude address    datetime  datetimeEpoch  tempmax  tempmin  \
# 0   48.8572    2.34141   Paris  2014-01-01     1388530800     10.5      6.7
# 1   48.8572    2.34141   Paris  2014-01-02     1388617200     11.1      8.5
# 2   48.8572    2.34141   Paris  2014-01-03     1388703600     13.4      8.5
# 3   48.8572    2.34141   Paris  2014-01-04     1388790000     12.4      7.6
# 4   48.8572    2.34141   Paris  2014-01-05     1388876400      8.9      4.6
#
#    temp  humidity  precip  ...              conditions  \
# 0   8.4     85.06    1.82  ...  Rain, Partially cloudy
# 1   9.9     81.63    4.96  ...                    Rain
# 2  11.0     76.53    0.14  ...  Rain, Partially cloudy
# 3   9.1     80.53    0.67  ...  Rain, Partially cloudy
# 4   6.9     82.81    1.25  ...  Rain, Partially cloudy
#
#                                          description        date  pm25  pm10  \
# 0        Partly cloudy throughout the day with rain.  2014-01-01  43.0  30.0
# 1  Clear conditions throughout the day with rain ...  2014-01-02  53.0  33.0
# 2  Partly cloudy throughout the day with morning ...  2014-01-03  50.0  28.0
# 3  Partly cloudy throughout the day with rain in ...  2014-01-04  52.0  23.0
# 4  Partly cloudy throughout the day with rain cle...  2014-01-05  45.0  20.0
#
#      o3   no2  so2   co   City
# 0  22.0  42.0  NaN  4.0  Paris
# 1  22.0  34.0  NaN  2.0  Paris
# 2  23.0  41.0  NaN  3.0  Paris
# 3  19.0  34.0  NaN  3.0  Paris
# 4  20.0  30.0  NaN  3.0  Paris
#
# [5 rows x 31 columns]

# %% [markdown]
# I will load the clean air pollution for Paris and concatanate it to the df, but first I will drop the columns that I will replace with clean data

# %%
paris_ml.columns
# Out:
# Index(['latitude', 'longitude', 'address', 'datetime', 'datetimeEpoch',
#        'tempmax', 'tempmin', 'temp', 'humidity', 'precip', 'precipcover',
#        'snow', 'snowdepth', 'windgust', 'windspeed', 'pressure', 'cloudcover',
#        'visibility', 'solarradiation', 'solarenergy', 'uvindex', 'conditions',
#        'description', 'date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co',
#        'City'],
#       dtype='object')

# %%
paris_ml.drop(columns=['date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co',
       'City'], inplace=True)

# %%
paris_clean = pd.read_csv(r'C:\Users\radek\Git-Hub\Final_Project_Ironhack\05 - Time Series\Paris_clean_for_ts.csv')

# %%
paris_clean.drop(columns='datetime', inplace=True)

# %%
paris_ml = pd.concat([paris_ml,paris_clean], axis=1)

# %%
paris_ml.head()
# Out:
#    latitude  longitude address    datetime  datetimeEpoch  tempmax  tempmin  \
# 0   48.8572    2.34141   Paris  2014-01-01     1388530800     10.5      6.7
# 1   48.8572    2.34141   Paris  2014-01-02     1388617200     11.1      8.5
# 2   48.8572    2.34141   Paris  2014-01-03     1388703600     13.4      8.5
# 3   48.8572    2.34141   Paris  2014-01-04     1388790000     12.4      7.6
# 4   48.8572    2.34141   Paris  2014-01-05     1388876400      8.9      4.6
#
#    temp  humidity  precip  ...  visibility  solarradiation  solarenergy  \
# 0   8.4     85.06    1.82  ...        24.8             NaN          NaN
# 1   9.9     81.63    4.96  ...        24.3             NaN          NaN
# 2  11.0     76.53    0.14  ...        20.4             NaN          NaN
# 3   9.1     80.53    0.67  ...        21.6             NaN          NaN
# 4   6.9     82.81    1.25  ...        24.0             NaN          NaN
#
#    uvindex              conditions  \
# 0      0.0  Rain, Partially cloudy
# 1      0.0                    Rain
# 2      0.0  Rain, Partially cloudy
# 3      0.0  Rain, Partially cloudy
# 4      0.0  Rain, Partially cloudy
#
#                                          description  pm25  pm10    o3   no2
# 0        Partly cloudy throughout the day with rain.  43.0  30.0  22.0  42.0
# 1  Clear conditions throughout the day with rain ...  53.0  33.0  22.0  34.0
# 2  Partly cloudy throughout the day with morning ...  50.0  28.0  23.0  41.0
# 3  Partly cloudy throughout the day with rain in ...  52.0  23.0  19.0  34.0
# 4  Partly cloudy throughout the day with rain cle...  45.0  20.0  20.0  30.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Dropping columns that diplicate information and that won't be needed for the analysis

# %%
paris_ml.columns
# Out:
# Index(['latitude', 'longitude', 'address', 'datetime', 'datetimeEpoch',
#        'tempmax', 'tempmin', 'temp', 'humidity', 'precip', 'precipcover',
#        'snow', 'snowdepth', 'windgust', 'windspeed', 'pressure', 'cloudcover',
#        'visibility', 'solarradiation', 'solarenergy', 'uvindex', 'conditions',
#        'description', 'pm25', 'pm10', 'o3', 'no2'],
#       dtype='object')

# %%
cols_to_drop = ['latitude', 'longitude', 'address', 'datetimeEpoch','description',]

# %%
paris_ml.drop(columns=cols_to_drop, inplace=True)

# %%
paris_ml.head()
# Out:
#      datetime  tempmax  tempmin  temp  humidity  precip  precipcover  snow  \
# 0  2014-01-01     10.5      6.7   8.4     85.06    1.82        16.67   NaN
# 1  2014-01-02     11.1      8.5   9.9     81.63    4.96        20.83   NaN
# 2  2014-01-03     13.4      8.5  11.0     76.53    0.14         4.17   NaN
# 3  2014-01-04     12.4      7.6   9.1     80.53    0.67         8.33   NaN
# 4  2014-01-05      8.9      4.6   6.9     82.81    1.25        12.50   NaN
#
#    snowdepth  windgust  ...  cloudcover  visibility  solarradiation  \
# 0        1.0      65.2  ...        26.7        24.8             NaN
# 1        1.0      60.2  ...        19.7        24.3             NaN
# 2        1.0      64.0  ...        20.1        20.4             NaN
# 3        1.0      45.7  ...        22.2        21.6             NaN
# 4        NaN      52.5  ...        22.8        24.0             NaN
#
#    solarenergy  uvindex              conditions  pm25  pm10    o3   no2
# 0          NaN      0.0  Rain, Partially cloudy  43.0  30.0  22.0  42.0
# 1          NaN      0.0                    Rain  53.0  33.0  22.0  34.0
# 2          NaN      0.0  Rain, Partially cloudy  50.0  28.0  23.0  41.0
# 3          NaN      0.0  Rain, Partially cloudy  52.0  23.0  19.0  34.0
# 4          NaN      0.0  Rain, Partially cloudy  45.0  20.0  20.0  30.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Missing values

# %%
paris_ml.shape
# Out:
# (2922, 22)

# %%
paris_ml.isna().sum()
# Out:
# datetime             0
# tempmax              0
# tempmin              0
# temp                 0
# humidity             0
# precip               1
# precipcover          1
# snow              2922
# snowdepth         2722
# windgust             1
# windspeed            0
# pressure             1
# cloudcover           1
# visibility           0
# solarradiation    1826
# solarenergy       1826
# uvindex              0
# conditions           0
# pm25                 0
# pm10                 0
# o3                   0
# no2                  0
# dtype: int64

# %%
'''The columns with mmost missing values are: solarrradiation, solarenergy, snow, snowdepth.
As these columns are given in paris I would assume that they are highly correlated and at leat 2 of them can be droped, but to better understand the data I will look at both of them.
I decided to drop them as these columns have missing values for more than a half records.'''
# Out:
# 'The columns with mmost missing values are: solarrradiation, solarenergy, snow, snowdepth.\nAs these columns are given in paris I would assume that they are highly correlated and at leat 2 of them can be droped, but to better understand the data I will look at both of them.\nI decided to drop them as these columns have missing values for more than a half records.'

# %%
cols_to_drop = ['snow', 'snowdepth','solarradiation', 'solarenergy']
paris_ml.drop(columns=cols_to_drop, inplace=True)

# %%
paris_ml.head()
# Out:
#      datetime  tempmax  tempmin  temp  humidity  precip  precipcover  \
# 0  2014-01-01     10.5      6.7   8.4     85.06    1.82        16.67
# 1  2014-01-02     11.1      8.5   9.9     81.63    4.96        20.83
# 2  2014-01-03     13.4      8.5  11.0     76.53    0.14         4.17
# 3  2014-01-04     12.4      7.6   9.1     80.53    0.67         8.33
# 4  2014-01-05      8.9      4.6   6.9     82.81    1.25        12.50
#
#    windgust  windspeed  pressure  cloudcover  visibility  uvindex  \
# 0      65.2       28.9    1006.1        26.7        24.8      0.0
# 1      60.2       29.2    1001.7        19.7        24.3      0.0
# 2      64.0       29.2    1006.0        20.1        20.4      0.0
# 3      45.7       21.5    1001.5        22.2        21.6      0.0
# 4      52.5       22.8    1007.5        22.8        24.0      0.0
#
#                conditions  pm25  pm10    o3   no2
# 0  Rain, Partially cloudy  43.0  30.0  22.0  42.0
# 1                    Rain  53.0  33.0  22.0  34.0
# 2  Rain, Partially cloudy  50.0  28.0  23.0  41.0
# 3  Rain, Partially cloudy  52.0  23.0  19.0  34.0
# 4  Rain, Partially cloudy  45.0  20.0  20.0  30.0

# %%
paris_ml.isna().sum()
# Out:
# datetime       0
# tempmax        0
# tempmin        0
# temp           0
# humidity       0
# precip         1
# precipcover    1
# windgust       1
# windspeed      0
# pressure       1
# cloudcover     1
# visibility     0
# uvindex        0
# conditions     0
# pm25           0
# pm10           0
# o3             0
# no2            0
# dtype: int64

# %% [markdown]
# I start by checking missing values on precipitation

# %%
paris_ml.loc[paris_ml.precip.isna()]
# Out:
#         datetime  tempmax  tempmin  temp  humidity  precip  precipcover  \
# 2607  2021-02-20     17.9      8.0  12.5      67.7     NaN          NaN
#
#       windgust  windspeed  pressure  cloudcover  visibility  uvindex  \
# 2607      34.2       24.8    1010.7        56.1        11.2      4.0
#
#             conditions  pm25  pm10    o3   no2
# 2607  Partially cloudy  55.0  16.0  26.0  13.0

# %%
#It seems that there was no percipiatation that day as conditions say paritally cloudly, so I can fill the values of precip and precipcover with 0
paris_ml.loc[paris_ml.precip.isna()] = paris_ml.loc[paris_ml.precip.isna()].fillna(0)

# %%
paris_ml.isna().sum()
# Out:
# datetime       0
# tempmax        0
# tempmin        0
# temp           0
# humidity       0
# precip         0
# precipcover    0
# windgust       1
# windspeed      0
# pressure       1
# cloudcover     1
# visibility     0
# uvindex        0
# conditions     0
# pm25           0
# pm10           0
# o3             0
# no2            0
# dtype: int64

# %% [markdown]
# Now I will look at windgust

# %%
paris_ml.loc[paris_ml.windgust.isna()]
# Out:
#         datetime  tempmax  tempmin  temp  humidity  precip  precipcover  \
# 2599  2021-02-12      0.6     -4.0  -2.2     58.86     0.0          0.0
#
#       windgust  windspeed  pressure  cloudcover  visibility  uvindex  \
# 2599       NaN       29.8       NaN         NaN        10.0      3.0
#
#      conditions  pm25  pm10    o3   no2
# 2599      Clear  64.0  25.0  25.0  30.0

# %%
# In fact wind gust (max speed is highly correlated to the wind speed so I can just drop this column istead of wondering how to fill that value)

# %%
paris_ml.drop(columns='windgust', inplace=True)

# %%
paris_ml.isna().sum()
# Out:
# datetime       0
# tempmax        0
# tempmin        0
# temp           0
# humidity       0
# precip         0
# precipcover    0
# windspeed      0
# pressure       1
# cloudcover     1
# visibility     0
# uvindex        0
# conditions     0
# pm25           0
# pm10           0
# o3             0
# no2            0
# dtype: int64

# %% [markdown]
# Let's look at pressure

# %%
paris_ml.loc[paris_ml.pressure.isna()]
# Out:
#         datetime  tempmax  tempmin  temp  humidity  precip  precipcover  \
# 2599  2021-02-12      0.6     -4.0  -2.2     58.86     0.0          0.0
#
#       windspeed  pressure  cloudcover  visibility  uvindex conditions  pm25  \
# 2599       29.8       NaN         NaN        10.0      3.0      Clear  64.0
#
#       pm10    o3   no2
# 2599  25.0  25.0  30.0

# %%
paris_ml.loc[[2598,2599,2600]]
# Out:
#         datetime  tempmax  tempmin  temp  humidity  precip  precipcover  \
# 2598  2021-02-11     -0.1     -6.1  -2.9     69.30     0.0          0.0
# 2599  2021-02-12      0.6     -4.0  -2.2     58.86     0.0          0.0
# 2600  2021-02-13      0.1     -6.1  -2.9     52.99     0.0          0.0
#
#       windspeed  pressure  cloudcover  visibility  uvindex        conditions  \
# 2598       36.0    1022.5        25.0        10.4      4.0  Partially cloudy
# 2599       29.8       NaN         NaN        10.0      3.0             Clear
# 2600       23.0    1033.5         9.7        16.8      4.0             Clear
#
#       pm25  pm10    o3   no2
# 2598  98.0  37.0  23.0  34.0
# 2599  64.0  25.0  25.0  30.0
# 2600  59.0  22.0  23.0  19.0

# %%
#I can assume that the pressure on that day was not that diffreent as the day after as they have the same conditions, so I will fill these values with the values for the day after

# %%
paris_ml=paris_ml.fillna(method='bfill')

# %%
paris_ml.loc[[2598,2599,2600]]
# Out:
#         datetime  tempmax  tempmin  temp  humidity  precip  precipcover  \
# 2598  2021-02-11     -0.1     -6.1  -2.9     69.30     0.0          0.0
# 2599  2021-02-12      0.6     -4.0  -2.2     58.86     0.0          0.0
# 2600  2021-02-13      0.1     -6.1  -2.9     52.99     0.0          0.0
#
#       windspeed  pressure  cloudcover  visibility  uvindex        conditions  \
# 2598       36.0    1022.5        25.0        10.4      4.0  Partially cloudy
# 2599       29.8    1033.5         9.7        10.0      3.0             Clear
# 2600       23.0    1033.5         9.7        16.8      4.0             Clear
#
#       pm25  pm10    o3   no2
# 2598  98.0  37.0  23.0  34.0
# 2599  64.0  25.0  25.0  30.0
# 2600  59.0  22.0  23.0  19.0

# %% [markdown]
# ### Converting datetime into datetime format

# %%
paris_ml.datetime= pd.to_datetime(paris_ml.datetime)

# %%
paris_ml.dtypes
# Out:
# datetime       datetime64[ns]
# tempmax               float64
# tempmin               float64
# temp                  float64
# humidity              float64
# precip                float64
# precipcover           float64
# windspeed             float64
# pressure              float64
# cloudcover            float64
# visibility            float64
# uvindex               float64
# conditions             object
# pm25                  float64
# pm10                  float64
# o3                    float64
# no2                   float64
# dtype: object

# %% [markdown]
# #### Encoding conditions

# %%
paris_ml.conditions.value_counts()
# Out:
# Clear                     990
# Rain, Partially cloudy    952
# Rain                      751
# Partially cloudy          217
# Snow, Partially cloudy     11
# Rain, Overcast              1
# Name: conditions, dtype: int64

# %%
paris_ml.conditions.unique()
# Out:
# array(['Rain, Partially cloudy', 'Rain', 'Partially cloudy', 'Clear',
#        'Snow, Partially cloudy', 'Rain, Overcast'], dtype=object)

# %%
event_list = ['Clear', 'Partially cloudy', 'Rain', 'Snow', 'Overcast']

# I am creating empty columns that will be populated with values if that event happend that day 
for event in event_list:
	paris_ml[event]=0

for event in event_list:
	paris_ml[event] = paris_ml['conditions'].str.contains(event).astype(int)

# %%
paris_ml.head()
# Out:
#     datetime  tempmax  tempmin  temp  humidity  precip  precipcover  \
# 0 2014-01-01     10.5      6.7   8.4     85.06    1.82        16.67
# 1 2014-01-02     11.1      8.5   9.9     81.63    4.96        20.83
# 2 2014-01-03     13.4      8.5  11.0     76.53    0.14         4.17
# 3 2014-01-04     12.4      7.6   9.1     80.53    0.67         8.33
# 4 2014-01-05      8.9      4.6   6.9     82.81    1.25        12.50
#
#    windspeed  pressure  cloudcover  ...              conditions  pm25  pm10  \
# 0       28.9    1006.1        26.7  ...  Rain, Partially cloudy  43.0  30.0
# 1       29.2    1001.7        19.7  ...                    Rain  53.0  33.0
# 2       29.2    1006.0        20.1  ...  Rain, Partially cloudy  50.0  28.0
# 3       21.5    1001.5        22.2  ...  Rain, Partially cloudy  52.0  23.0
# 4       22.8    1007.5        22.8  ...  Rain, Partially cloudy  45.0  20.0
#
#      o3   no2  Clear  Partially cloudy  Rain  Snow  Overcast
# 0  22.0  42.0      0                 1     1     0         0
# 1  22.0  34.0      0                 0     1     0         0
# 2  23.0  41.0      0                 1     1     0         0
# 3  19.0  34.0      0                 1     1     0         0
# 4  20.0  30.0      0                 1     1     0         0
#
# [5 rows x 22 columns]

# %%
#Now I can drop coditions column
paris_ml.drop(columns='conditions', inplace=True)

# %% [markdown]
# #### Extracting month and day information

# %%
#As in the model I don't need the exact day only the information about the month and day of the week, as these propabbly influence air pollution eg. higher pollution for winter months, lower pollution during weekends etc

paris_ml['month']=paris_ml.datetime.dt.month
paris_ml['day_of_week'] = paris_ml.datetime.dt.dayofweek

# %%
#I will save this version of the file with date for EDA wihich will be perfomed later
paris_ml.to_csv(r'C:\Users\radek\Git-Hub\Final_Project_Ironhack\07 - EDA\Paris_for_EDA.csv', index_label=False)

# %%
#Now I can drop datetime column
paris_ml.drop(columns='datetime', inplace=True)

# %% [markdown]
# ### Correlation between columns

# %%
# I will drow correlation matrix as well as see values in the Table 
sns.set_theme(style="whitegrid")
# Compute the correlation matrix
corr = paris_ml.corr()
f, ax = plt.subplots(figsize=(11, 9))
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Generate a custom diverging colormap
cmap = 'YlGnBu'

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                    tempmax   tempmin      temp  humidity    precip  \
# tempmax           1.000000  0.906268  0.981934 -0.607853 -0.026350
# tempmin           0.906268  1.000000  0.964138 -0.377490  0.081912
# temp              0.981934  0.964138  1.000000 -0.536448  0.011417
# humidity         -0.607853 -0.377490 -0.536448  1.000000  0.316510
# precip           -0.026350  0.081912  0.011417  0.316510  1.000000
# precipcover      -0.215296 -0.042097 -0.153123  0.533096  0.720776
# windspeed        -0.171001 -0.104070 -0.141594  0.061672  0.193937
# pressure         -0.000768 -0.102921 -0.040602 -0.199473 -0.336365
# cloudcover       -0.365606 -0.107342 -0.264683  0.588037  0.263663
# visibility        0.470824  0.439660  0.474633 -0.520212 -0.128319
# uvindex           0.291618  0.210281  0.264137 -0.341646 -0.055118
# pm25             -0.201978 -0.320200 -0.263085  0.052022 -0.153583
# pm10              0.115401 -0.014136  0.064246 -0.304003 -0.200154
# o3                0.670881  0.560169  0.647726 -0.600843 -0.016577
# no2               0.058488 -0.036531  0.021730 -0.145370 -0.092020
# Clear             0.298325  0.085348  0.223984 -0.575379 -0.296366
# Partially cloudy -0.338448 -0.113512 -0.249645  0.498449  0.283825
# Rain             -0.207084 -0.033565 -0.148296  0.523705  0.347516
# Snow             -0.128908 -0.137876 -0.133972  0.051832 -0.005220
# Overcast         -0.006277  0.000624 -0.001889  0.029671  0.006090
# month             0.161357  0.245580  0.198828  0.146356  0.014709
# day_of_week       0.012689  0.001339  0.005906  0.016541 -0.007029
#
#                   precipcover  windspeed  pressure  cloudcover  visibility  \
# tempmax             -0.215296  -0.171001 -0.000768   -0.365606    0.470824
# tempmin             -0.042097  -0.104070 -0.102921   -0.107342    0.439660
# temp                -0.153123  -0.141594 -0.040602   -0.264683    0.474633
# humidity             0.533096   0.061672 -0.199473    0.588037   -0.520212
# precip               0.720776   0.193937 -0.336365    0.263663   -0.128319
# precipcover          1.000000   0.322276 -0.483296    0.463381   -0.166747
# windspeed            0.322276   1.000000 -0.361666    0.253470    0.188713
# pressure            -0.483296  -0.361666  1.000000   -0.304442   -0.161645
# cloudcover           0.463381   0.253470 -0.304442    1.000000   -0.152358
# visibility          -0.166747   0.188713 -0.161645   -0.152358    1.000000
# uvindex             -0.132217   0.001673  0.048871   -0.242008    0.159178
# pm25                -0.268719  -0.400341  0.307568   -0.189296   -0.625761
# pm10                -0.341247  -0.318186  0.323179   -0.348699   -0.120537
# o3                  -0.139876   0.020343 -0.054560   -0.315870    0.413155
# no2                 -0.132668  -0.218085  0.111044   -0.183914    0.000736
# Clear               -0.546926  -0.205752  0.325537   -0.607677    0.131804
# Partially cloudy     0.485756   0.219628 -0.291892    0.753999   -0.159298
# Rain                 0.636167   0.232436 -0.366665    0.428408   -0.100711
# Snow                 0.031844   0.011115 -0.026157    0.072715   -0.137856
# Overcast             0.029353  -0.023607  0.017596    0.140659   -0.013355
# month                0.015042  -0.177125  0.038124    0.037516   -0.008080
# day_of_week          0.007660   0.020433 -0.029445   -0.001008   -0.019371
#
#                   ...      pm10        o3       no2     Clear  \
# tempmax           ...  0.115401  0.670881  0.058488  0.298325
# tempmin           ... -0.014136  0.560169 -0.036531  0.085348
# temp              ...  0.064246  0.647726  0.021730  0.223984
# humidity          ... -0.304003 -0.600843 -0.145370 -0.575379
# precip            ... -0.200154 -0.016577 -0.092020 -0.296366
# precipcover       ... -0.341247 -0.139876 -0.132668 -0.546926
# windspeed         ... -0.318186  0.020343 -0.218085 -0.205752
# pressure          ...  0.323179 -0.054560  0.111044  0.325537
# cloudcover        ... -0.348699 -0.315870 -0.183914 -0.607677
# visibility        ... -0.120537  0.413155  0.000736  0.131804
# uvindex           ... -0.247520  0.305827 -0.473040  0.185310
# pm25              ...  0.532436 -0.229680  0.407801  0.188911
# pm10              ...  1.000000  0.110273  0.669083  0.315080
# o3                ...  0.110273  1.000000  0.112454  0.299158
# no2               ...  0.669083  0.112454  1.000000  0.150757
# Clear             ...  0.315080  0.299158  0.150757  1.000000
# Partially cloudy  ... -0.286774 -0.251957 -0.152201 -0.589157
# Rain              ... -0.324714 -0.215333 -0.134187 -0.846691
# Snow              ...  0.013979 -0.062562  0.007350 -0.044004
# Overcast          ... -0.022225 -0.023515 -0.024835 -0.013245
# month             ... -0.093308 -0.150928 -0.113375 -0.086319
# day_of_week       ... -0.084903  0.031375 -0.118053 -0.000362
#
#                   Partially cloudy          Rain      Snow  Overcast  \
# tempmax                  -0.338448 -2.070837e-01 -0.128908 -0.006277
# tempmin                  -0.113512 -3.356525e-02 -0.137876  0.000624
# temp                     -0.249645 -1.482964e-01 -0.133972 -0.001889
# humidity                  0.498449  5.237049e-01  0.051832  0.029671
# precip                    0.283825  3.475160e-01 -0.005220  0.006090
# precipcover               0.485756  6.361671e-01  0.031844  0.029353
# windspeed                 0.219628  2.324357e-01  0.011115 -0.023607
# pressure                 -0.291892 -3.666654e-01 -0.026157  0.017596
# cloudcover                0.753999  4.284084e-01  0.072715  0.140659
# visibility               -0.159298 -1.007112e-01 -0.137856 -0.013355
# uvindex                  -0.198416 -1.400668e-01 -0.023984  0.003364
# pm25                     -0.160264 -2.283360e-01  0.104651 -0.006442
# pm10                     -0.286774 -3.247145e-01  0.013979 -0.022225
# o3                       -0.251957 -2.153328e-01 -0.062562 -0.023515
# no2                      -0.152201 -1.341872e-01  0.007350 -0.024835
# Clear                    -0.589157 -8.466915e-01 -0.044004 -0.013245
# Partially cloudy          1.000000  3.732883e-01  0.074689 -0.015228
# Rain                      0.373288  1.000000e+00 -0.072709  0.015643
# Snow                      0.074689 -7.270870e-02  1.000000 -0.001137
# Overcast                 -0.015228  1.564311e-02 -0.001137  1.000000
# month                    -0.017405  9.418135e-02 -0.067656  0.024020
# day_of_week              -0.016747  7.370476e-17 -0.019568 -0.018511
#
#                      month   day_of_week
# tempmax           0.161357  1.268898e-02
# tempmin           0.245580  1.338959e-03
# temp              0.198828  5.906358e-03
# humidity          0.146356  1.654096e-02
# precip            0.014709 -7.029033e-03
# precipcover       0.015042  7.659814e-03
# windspeed        -0.177125  2.043255e-02
# pressure          0.038124 -2.944525e-02
# cloudcover        0.037516 -1.008051e-03
# visibility       -0.008080 -1.937136e-02
# uvindex          -0.011493 -8.280028e-03
# pm25             -0.089104  1.617107e-02
# pm10             -0.093308 -8.490317e-02
# o3               -0.150928  3.137513e-02
# no2              -0.113375 -1.180530e-01
# Clear            -0.086319 -3.616885e-04
# Partially cloudy -0.017405 -1.674681e-02
# Rain              0.094181  7.370476e-17
# Snow             -0.067656 -1.956755e-02
# Overcast          0.024020 -1.851058e-02
# month             1.000000 -1.240966e-03
# day_of_week      -0.001241  1.000000e+00
#
# [22 rows x 22 columns]

# %%
#There are a lot of columns that are highly correlated I will deal with them one by one.
# I can drop tempmax and tempmin as they are highly correlated to temp
# I can drop as well precipcover as it is correlated to precip

cols_to_drop = ['tempmax', 'tempmin', 'precipcover']
paris_ml.drop(columns=cols_to_drop, inplace=True)

# %%
#Now I look at the correlation matrix again
paris_ml.corr()
# Out:
#                       temp  humidity    precip  windspeed  pressure  \
# temp              1.000000 -0.536448  0.011417  -0.141594 -0.040602
# humidity         -0.536448  1.000000  0.316510   0.061672 -0.199473
# precip            0.011417  0.316510  1.000000   0.193937 -0.336365
# windspeed        -0.141594  0.061672  0.193937   1.000000 -0.361666
# pressure         -0.040602 -0.199473 -0.336365  -0.361666  1.000000
# cloudcover       -0.264683  0.588037  0.263663   0.253470 -0.304442
# visibility        0.474633 -0.520212 -0.128319   0.188713 -0.161645
# uvindex           0.264137 -0.341646 -0.055118   0.001673  0.048871
# pm25             -0.263085  0.052022 -0.153583  -0.400341  0.307568
# pm10              0.064246 -0.304003 -0.200154  -0.318186  0.323179
# o3                0.647726 -0.600843 -0.016577   0.020343 -0.054560
# no2               0.021730 -0.145370 -0.092020  -0.218085  0.111044
# Clear             0.223984 -0.575379 -0.296366  -0.205752  0.325537
# Partially cloudy -0.249645  0.498449  0.283825   0.219628 -0.291892
# Rain             -0.148296  0.523705  0.347516   0.232436 -0.366665
# Snow             -0.133972  0.051832 -0.005220   0.011115 -0.026157
# Overcast         -0.001889  0.029671  0.006090  -0.023607  0.017596
# month             0.198828  0.146356  0.014709  -0.177125  0.038124
# day_of_week       0.005906  0.016541 -0.007029   0.020433 -0.029445
#
#                   cloudcover  visibility   uvindex      pm25      pm10  \
# temp               -0.264683    0.474633  0.264137 -0.263085  0.064246
# humidity            0.588037   -0.520212 -0.341646  0.052022 -0.304003
# precip              0.263663   -0.128319 -0.055118 -0.153583 -0.200154
# windspeed           0.253470    0.188713  0.001673 -0.400341 -0.318186
# pressure           -0.304442   -0.161645  0.048871  0.307568  0.323179
# cloudcover          1.000000   -0.152358 -0.242008 -0.189296 -0.348699
# visibility         -0.152358    1.000000  0.159178 -0.625761 -0.120537
# uvindex            -0.242008    0.159178  1.000000 -0.284420 -0.247520
# pm25               -0.189296   -0.625761 -0.284420  1.000000  0.532436
# pm10               -0.348699   -0.120537 -0.247520  0.532436  1.000000
# o3                 -0.315870    0.413155  0.305827 -0.229680  0.110273
# no2                -0.183914    0.000736 -0.473040  0.407801  0.669083
# Clear              -0.607677    0.131804  0.185310  0.188911  0.315080
# Partially cloudy    0.753999   -0.159298 -0.198416 -0.160264 -0.286774
# Rain                0.428408   -0.100711 -0.140067 -0.228336 -0.324714
# Snow                0.072715   -0.137856 -0.023984  0.104651  0.013979
# Overcast            0.140659   -0.013355  0.003364 -0.006442 -0.022225
# month               0.037516   -0.008080 -0.011493 -0.089104 -0.093308
# day_of_week        -0.001008   -0.019371 -0.008280  0.016171 -0.084903
#
#                         o3       no2     Clear  Partially cloudy  \
# temp              0.647726  0.021730  0.223984         -0.249645
# humidity         -0.600843 -0.145370 -0.575379          0.498449
# precip           -0.016577 -0.092020 -0.296366          0.283825
# windspeed         0.020343 -0.218085 -0.205752          0.219628
# pressure         -0.054560  0.111044  0.325537         -0.291892
# cloudcover       -0.315870 -0.183914 -0.607677          0.753999
# visibility        0.413155  0.000736  0.131804         -0.159298
# uvindex           0.305827 -0.473040  0.185310         -0.198416
# pm25             -0.229680  0.407801  0.188911         -0.160264
# pm10              0.110273  0.669083  0.315080         -0.286774
# o3                1.000000  0.112454  0.299158         -0.251957
# no2               0.112454  1.000000  0.150757         -0.152201
# Clear             0.299158  0.150757  1.000000         -0.589157
# Partially cloudy -0.251957 -0.152201 -0.589157          1.000000
# Rain             -0.215333 -0.134187 -0.846691          0.373288
# Snow             -0.062562  0.007350 -0.044004          0.074689
# Overcast         -0.023515 -0.024835 -0.013245         -0.015228
# month            -0.150928 -0.113375 -0.086319         -0.017405
# day_of_week       0.031375 -0.118053 -0.000362         -0.016747
#
#                           Rain      Snow  Overcast     month   day_of_week
# temp             -1.482964e-01 -0.133972 -0.001889  0.198828  5.906358e-03
# humidity          5.237049e-01  0.051832  0.029671  0.146356  1.654096e-02
# precip            3.475160e-01 -0.005220  0.006090  0.014709 -7.029033e-03
# windspeed         2.324357e-01  0.011115 -0.023607 -0.177125  2.043255e-02
# pressure         -3.666654e-01 -0.026157  0.017596  0.038124 -2.944525e-02
# cloudcover        4.284084e-01  0.072715  0.140659  0.037516 -1.008051e-03
# visibility       -1.007112e-01 -0.137856 -0.013355 -0.008080 -1.937136e-02
# uvindex          -1.400668e-01 -0.023984  0.003364 -0.011493 -8.280028e-03
# pm25             -2.283360e-01  0.104651 -0.006442 -0.089104  1.617107e-02
# pm10             -3.247145e-01  0.013979 -0.022225 -0.093308 -8.490317e-02
# o3               -2.153328e-01 -0.062562 -0.023515 -0.150928  3.137513e-02
# no2              -1.341872e-01  0.007350 -0.024835 -0.113375 -1.180530e-01
# Clear            -8.466915e-01 -0.044004 -0.013245 -0.086319 -3.616885e-04
# Partially cloudy  3.732883e-01  0.074689 -0.015228 -0.017405 -1.674681e-02
# Rain              1.000000e+00 -0.072709  0.015643  0.094181  7.370476e-17
# Snow             -7.270870e-02  1.000000 -0.001137 -0.067656 -1.956755e-02
# Overcast          1.564311e-02 -0.001137  1.000000  0.024020 -1.851058e-02
# month             9.418135e-02 -0.067656  0.024020  1.000000 -1.240966e-03
# day_of_week       7.370476e-17 -0.019568 -0.018511 -0.001241  1.000000e+00

# %%
sns.set_theme(style="whitegrid")
# Compute the correlation matrix
corr = paris_ml.corr()
f, ax = plt.subplots(figsize=(11, 9))
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Generate a custom diverging colormap
cmap = 'YlGnBu'

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
# I can leave rest of the columns like that as there is no correlation exceeding 90%

# %%
paris_ml.pm25.max()
# Out:
# 177.0

# %% [markdown]
# Outliers

# %%
paris_ml.columns
# Out:
# Index(['temp', 'humidity', 'precip', 'windspeed', 'pressure', 'cloudcover',
#        'visibility', 'uvindex', 'pm25', 'pm10', 'o3', 'no2', 'Clear',
#        'Partially cloudy', 'Rain', 'Snow', 'Overcast', 'month', 'day_of_week',
#        'target'],
#       dtype='object')

# %%
columns_boxplot = ['temp', 'humidity', 'precip', 'windspeed', 'pressure', 'cloudcover',
       'visibility', 'uvindex', 'pm25', 'pm10', 'o3', 'no2']

# %%
for col in columns_boxplot:
	sns.boxplot(paris_ml[col])
	plt.title(col)
	plt.show()
# Out:
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\radek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Creating a target variable

# %%
paris_ml['target']=pd.cut(paris_ml.pm25, bins=[0,50,100,200], labels=[0,1,2])

# %%
paris_ml['target'].value_counts()
# Out:
# 1    1876
# 0     839
# 2     207
# Name: target, dtype: int64

# %%
paris_ml.head()
# Out:
#    temp  humidity  precip  windspeed  pressure  cloudcover  visibility  \
# 0   8.4     85.06    1.82       28.9    1006.1        26.7        24.8
# 1   9.9     81.63    4.96       29.2    1001.7        19.7        24.3
# 2  11.0     76.53    0.14       29.2    1006.0        20.1        20.4
# 3   9.1     80.53    0.67       21.5    1001.5        22.2        21.6
# 4   6.9     82.81    1.25       22.8    1007.5        22.8        24.0
#
#    uvindex  pm25  pm10    o3   no2  Clear  Partially cloudy  Rain  Snow  \
# 0      0.0  43.0  30.0  22.0  42.0      0                 1     1     0
# 1      0.0  53.0  33.0  22.0  34.0      0                 0     1     0
# 2      0.0  50.0  28.0  23.0  41.0      0                 1     1     0
# 3      0.0  52.0  23.0  19.0  34.0      0                 1     1     0
# 4      0.0  45.0  20.0  20.0  30.0      0                 1     1     0
#
#    Overcast  month  day_of_week target
# 0         0      1            2      0
# 1         0      1            3      1
# 2         0      1            4      0
# 3         0      1            5      1
# 4         0      1            6      0

# %%
paris_ml.to_csv(r'C:\Users\radek\Git-Hub\Final_Project_Ironhack\06 - ML\paris_ready_for_ml.csv', index_label=False)
